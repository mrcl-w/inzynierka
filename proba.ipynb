# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re

# %%
billboard = pd.read_csv('hot100.csv')
billboard.columns
# Out:
# C:\Users\Marcel\AppData\Local\Temp\ipykernel_36776\3015988688.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   billboard = pd.read_csv('hot100.csv')
# Index(['Date', 'Song', 'Artist', 'Rank', 'Last Week', 'Peak Position',
#        'Weeks in Charts', 'Image URL'],
#       dtype='object')

# %%
billboard.drop(columns=['Image URL'], inplace=True)
billboard.head()
# Out:
#          Date                             Song                         Artist  \
# 0  1958-08-06                 Poor Little Fool                   Ricky Nelson
# 1  1958-08-06  Nel Blu Dipinto Di Blu (Volare)               Domenico Modugno
# 2  1958-08-06                         Patricia  Perez Prado And His Orchestra
# 3  1958-08-06                    Splish Splash                    Bobby Darin
# 4  1958-08-06                             When                    Kalin Twins
#
#    Rank Last Week  Peak Position Weeks in Charts
# 0     1         1              1               2
# 1     2        54              2               2
# 2     3         2              2               2
# 3     4         3              3               2
# 4     5         5              5               2

# %%
spotify = pd.read_csv('dataset-of-10s.csv')
spotify.head()
# Out:
#                                  track                          artist  \
# 0                          Wild Things                    Alessia Cara
# 1                            Surfboard                       Esquivel!
# 2                         Love Someone                    Lukas Graham
# 3  Music To My Ears (feat. Tory Lanez)                   Keys N Krates
# 4        Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:2ZyuwVvV6Z3XJaXIFbspeE         0.741   0.626    1    -4.826
# 1  spotify:track:61APOtq25SCMuK0V5w2Kgp         0.447   0.247    5   -14.661
# 2  spotify:track:2JqnpexlO9dmvjUMCaLCLJ         0.550   0.415    9    -6.557
# 3  spotify:track:0cjfLhk8WJ3etPTCseKXtk         0.502   0.648    0    -5.698
# 4  spotify:track:1lItf5ZXJc1by9SbPeljFd         0.807   0.887    1    -3.892
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0886       0.02000             0.000    0.0828    0.706
# 1     0       0.0346       0.87100             0.814    0.0946    0.250
# 2     0       0.0520       0.16100             0.000    0.1080    0.274
# 3     0       0.0527       0.00513             0.000    0.2040    0.291
# 4     1       0.2750       0.00381             0.000    0.3910    0.780
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target
# 0  108.029       188493               4    41.18681        10       1
# 1  155.489       176880               3    33.18083         9       0
# 2  172.065       205463               4    44.89147         9       1
# 3   91.837       193043               4    29.52521         7       0
# 4  160.517       144244               4    24.99199         8       1

# %%
def normalize_title(title):
    title = title.lower()
    title = re.sub(r"\(.*?\)", "", title) #remove text in parentheses
    title = re.sub(r"feat\.|featuring", "", title) #remove 'feat.' or 'featuring' -> can look into it later
    title = re.sub(r'[^a-z0-9\s]', '', title) #delete punctuation
    title = re.sub(r'\s+', ' ', title).strip() #remove extra spaces
    return title

# %%
billboard['Normalized Title'] = billboard['Song'].apply(normalize_title)
spotify['Normalized Title'] = spotify['track'].apply(normalize_title)

# %%
spotify.head()
# Out:
#                                  track                          artist  \
# 0                          Wild Things                    Alessia Cara
# 1                            Surfboard                       Esquivel!
# 2                         Love Someone                    Lukas Graham
# 3  Music To My Ears (feat. Tory Lanez)                   Keys N Krates
# 4        Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:2ZyuwVvV6Z3XJaXIFbspeE         0.741   0.626    1    -4.826
# 1  spotify:track:61APOtq25SCMuK0V5w2Kgp         0.447   0.247    5   -14.661
# 2  spotify:track:2JqnpexlO9dmvjUMCaLCLJ         0.550   0.415    9    -6.557
# 3  spotify:track:0cjfLhk8WJ3etPTCseKXtk         0.502   0.648    0    -5.698
# 4  spotify:track:1lItf5ZXJc1by9SbPeljFd         0.807   0.887    1    -3.892
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0886       0.02000             0.000    0.0828    0.706
# 1     0       0.0346       0.87100             0.814    0.0946    0.250
# 2     0       0.0520       0.16100             0.000    0.1080    0.274
# 3     0       0.0527       0.00513             0.000    0.2040    0.291
# 4     1       0.2750       0.00381             0.000    0.3910    0.780
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target  \
# 0  108.029       188493               4    41.18681        10       1
# 1  155.489       176880               3    33.18083         9       0
# 2  172.065       205463               4    44.89147         9       1
# 3   91.837       193043               4    29.52521         7       0
# 4  160.517       144244               4    24.99199         8       1
#
#     Normalized Title
# 0        wild things
# 1          surfboard
# 2       love someone
# 3   music to my ears
# 4  juju on that beat

# %%
merged_data = pd.merge(billboard, spotify, on='Normalized Title', how='inner', suffixes=('_billboard', '_spotify'))

# %%
merged_data['Weeks in Charts'] = pd.to_numeric(merged_data['Weeks in Charts'], errors='coerce').astype('Int64')
merged_data['Weeks in Charts'] = merged_data['Weeks in Charts'].fillna(1).astype(int)

# %%
#merged_data.head()
#merged_data["Weeks in Charts"] = int(merged_data["Weeks in Charts"])
filtered_data = merged_data[merged_data['Normalized Title'] == 'we are never ever getting back together']
#filtered_data = filtered_data[filtered_data["Weeks in Charts"] < 6]
filtered_data
# Out:
#              Date                                               Song  \
# 47378  2012-08-22            We Are Never Ever Getting Back Together
# 47412  2012-08-29            We Are Never Ever Getting Back Together
# 47532  2012-09-05            We Are Never Ever Getting Back Together
# 47654  2012-09-12            We Are Never Ever Getting Back Together
# 47774  2012-09-19            We Are Never Ever Getting Back Together
# 47895  2012-09-26            We Are Never Ever Getting Back Together
# 48015  2012-10-03            We Are Never Ever Getting Back Together
# 48139  2012-10-10            We Are Never Ever Getting Back Together
# 48260  2012-10-17            We Are Never Ever Getting Back Together
# 48373  2012-10-24            We Are Never Ever Getting Back Together
# 48487  2012-10-31            We Are Never Ever Getting Back Together
# 48612  2012-11-07            We Are Never Ever Getting Back Together
# 48713  2012-11-14            We Are Never Ever Getting Back Together
# 48829  2012-11-21            We Are Never Ever Getting Back Together
# 48943  2012-11-28            We Are Never Ever Getting Back Together
# 49059  2012-12-05            We Are Never Ever Getting Back Together
# 49170  2012-12-12            We Are Never Ever Getting Back Together
# 49291  2012-12-19            We Are Never Ever Getting Back Together
# 49405  2012-12-26            We Are Never Ever Getting Back Together
# 49518  2013-01-02            We Are Never Ever Getting Back Together
# 49611  2013-01-09            We Are Never Ever Getting Back Together
# 49730  2013-01-16            We Are Never Ever Getting Back Together
# 49852  2013-01-23            We Are Never Ever Getting Back Together
# 49971  2013-01-30            We Are Never Ever Getting Back Together
# 95466  2021-11-24  We Are Never Ever Getting Back Together (Taylo...
#
#              Artist  Rank Last Week  Peak Position  Weeks in Charts  \
# 47378  Taylor Swift    72        72              1                1
# 47412  Taylor Swift     1        72              1                2
# 47532  Taylor Swift     1         1              1                3
# 47654  Taylor Swift     2         1              1                4
# 47774  Taylor Swift     1         2              1                5
# 47895  Taylor Swift     2         1              1                6
# 48015  Taylor Swift     4         2              1                7
# 48139  Taylor Swift     4         4              1                8
# 48260  Taylor Swift     5         4              1                9
# 48373  Taylor Swift     5         5              1               10
# 48487  Taylor Swift     4         5              1               11
# 48612  Taylor Swift    11         4              1               12
# 48713  Taylor Swift     5        11              1               13
# 48829  Taylor Swift     7         5              1               14
# 48943  Taylor Swift     9         7              1               15
# 49059  Taylor Swift    11         9              1               16
# 49170  Taylor Swift    15        11              1               17
# 49291  Taylor Swift    25        15              1               18
# 49405  Taylor Swift    27        25              1               19
# 49518  Taylor Swift    29        27              1               20
# 49611  Taylor Swift    17        29              1               21
# 49730  Taylor Swift    25        17              1               22
# 49852  Taylor Swift    39        25              1               23
# 49971  Taylor Swift    46        39              1               24
# 95466  Taylor Swift    55        55              1                1
#
#                               Normalized Title  \
# 47378  we are never ever getting back together
# 47412  we are never ever getting back together
# 47532  we are never ever getting back together
# 47654  we are never ever getting back together
# 47774  we are never ever getting back together
# 47895  we are never ever getting back together
# 48015  we are never ever getting back together
# 48139  we are never ever getting back together
# 48260  we are never ever getting back together
# 48373  we are never ever getting back together
# 48487  we are never ever getting back together
# 48612  we are never ever getting back together
# 48713  we are never ever getting back together
# 48829  we are never ever getting back together
# 48943  we are never ever getting back together
# 49059  we are never ever getting back together
# 49170  we are never ever getting back together
# 49291  we are never ever getting back together
# 49405  we are never ever getting back together
# 49518  we are never ever getting back together
# 49611  we are never ever getting back together
# 49730  we are never ever getting back together
# 49852  we are never ever getting back together
# 49971  we are never ever getting back together
# 95466  we are never ever getting back together
#
#                                          track        artist  ...  \
# 47378  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 47412  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 47532  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 47654  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 47774  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 47895  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48015  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48139  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48260  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48373  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48487  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48612  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48713  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48829  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 48943  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49059  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49170  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49291  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49405  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49518  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49611  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49730  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49852  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 49971  We Are Never Ever Getting Back Together  Taylor Swift  ...
# 95466  We Are Never Ever Getting Back Together  Taylor Swift  ...
#
#       acousticness  instrumentalness  liveness  valence   tempo  duration_ms  \
# 47378      0.00957          0.000027     0.102     0.75  85.984       191880
# 47412      0.00957          0.000027     0.102     0.75  85.984       191880
# 47532      0.00957          0.000027     0.102     0.75  85.984       191880
# 47654      0.00957          0.000027     0.102     0.75  85.984       191880
# 47774      0.00957          0.000027     0.102     0.75  85.984       191880
# 47895      0.00957          0.000027     0.102     0.75  85.984       191880
# 48015      0.00957          0.000027     0.102     0.75  85.984       191880
# 48139      0.00957          0.000027     0.102     0.75  85.984       191880
# 48260      0.00957          0.000027     0.102     0.75  85.984       191880
# 48373      0.00957          0.000027     0.102     0.75  85.984       191880
# 48487      0.00957          0.000027     0.102     0.75  85.984       191880
# 48612      0.00957          0.000027     0.102     0.75  85.984       191880
# 48713      0.00957          0.000027     0.102     0.75  85.984       191880
# 48829      0.00957          0.000027     0.102     0.75  85.984       191880
# 48943      0.00957          0.000027     0.102     0.75  85.984       191880
# 49059      0.00957          0.000027     0.102     0.75  85.984       191880
# 49170      0.00957          0.000027     0.102     0.75  85.984       191880
# 49291      0.00957          0.000027     0.102     0.75  85.984       191880
# 49405      0.00957          0.000027     0.102     0.75  85.984       191880
# 49518      0.00957          0.000027     0.102     0.75  85.984       191880
# 49611      0.00957          0.000027     0.102     0.75  85.984       191880
# 49730      0.00957          0.000027     0.102     0.75  85.984       191880
# 49852      0.00957          0.000027     0.102     0.75  85.984       191880
# 49971      0.00957          0.000027     0.102     0.75  85.984       191880
# 95466      0.00957          0.000027     0.102     0.75  85.984       191880
#
#        time_signature  chorus_hit  sections  target
# 47378               4    29.57263         7       1
# 47412               4    29.57263         7       1
# 47532               4    29.57263         7       1
# 47654               4    29.57263         7       1
# 47774               4    29.57263         7       1
# 47895               4    29.57263         7       1
# 48015               4    29.57263         7       1
# 48139               4    29.57263         7       1
# 48260               4    29.57263         7       1
# 48373               4    29.57263         7       1
# 48487               4    29.57263         7       1
# 48612               4    29.57263         7       1
# 48713               4    29.57263         7       1
# 48829               4    29.57263         7       1
# 48943               4    29.57263         7       1
# 49059               4    29.57263         7       1
# 49170               4    29.57263         7       1
# 49291               4    29.57263         7       1
# 49405               4    29.57263         7       1
# 49518               4    29.57263         7       1
# 49611               4    29.57263         7       1
# 49730               4    29.57263         7       1
# 49852               4    29.57263         7       1
# 49971               4    29.57263         7       1
# 95466               4    29.57263         7       1
#
# [25 rows x 27 columns]
